# %% [markdown]
# Import the "Avengers" data from the [FiveThirtyEight data repository on GitHub](https://github.com/fivethirtyeight/data/blob/master/avengers/avengers.csv).

# %%
library('tidyverse')
# Out:
# Warning message:
# “replacing previous import ‘vctrs::data_frame’ by ‘tibble::data_frame’ when loading ‘dplyr’”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
Avengers<-read_csv("https://github.com/fivethirtyeight/data/raw/master/avengers/avengers.csv")
Avengers%>%head
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   Appearances = col_double(),
#   Year = col_double(),
#   `Years since joining` = col_double()
# )
#
# See spec(...) for full column specifications.
#   URL
# 1 http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 2 http://marvel.wikia.com/Janet_van_Dyne_(Earth-616)
# 3 http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 4 http://marvel.wikia.com/Robert_Bruce_Banner_(Earth-616)
# 5 http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 6 http://marvel.wikia.com/Richard_Jones_(Earth-616)
#   Name/Alias                  Appearances Current? Gender Probationary Introl
# 1 Henry Jonathan "Hank" Pym   1269        YES      MALE   NA
# 2 Janet van Dyne              1165        YES      FEMALE NA
# 3 Anthony Edward "Tony" Stark 3068        YES      MALE   NA
# 4 Robert Bruce Banner         2089        YES      MALE   NA
# 5 Thor Odinson                2402        YES      MALE   NA
# ...

# %% [markdown]
# Make an ECDF plot of `Appearances`.

# %%
options(repr.plot.res =120, repr.plot.height=3, repr.plot.width=5)
p=ggplot(Avengers, aes(x=Appearances))
p=p+stat_ecdf(geom="line")
p
# Out:
# plot without title

# %% [markdown]
# CSV
#
# if first row is not the header: col_names=false

# %% [markdown]
# TSV
#
# TAB SEPERATED `\t`

# %% [markdown]
# json
#
# {"col1:1,"col 2":2}

# %% [markdown]
# # notes
#
# read.csv--> data frame
#
# read_csv --> tibble
#
# tables expect col names to start with a character
#
# if you need to refer to a col name starting with a number use back ticks {`i`}
